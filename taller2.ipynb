# %%
# -------------------------------
# Bibliotecas estándar
# -------------------------------
from datetime import datetime

# -------------------------------
# Bibliotecas científicas y de manipulación de datos
# -------------------------------
import numpy as np
import pandas as pd
import tensorflow as tf

# -------------------------------
# Bibliotecas de visualización
# -------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------
# Bibliotecas de scikit-learn
# -------------------------------
from sklearn.model_selection import train_test_split, ParameterGrid, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import (confusion_matrix, precision_score, accuracy_score, 
                             recall_score, f1_score, roc_curve, auc)

# -------------------------------
# Bibliotecas de Keras y TensorFlow
# -------------------------------
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, GlobalAveragePooling1D, MultiHeadAttention, LayerNormalization, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import pad_sequences

# -------------------------------
# Métricas de Keras
# -------------------------------
from tensorflow.keras.metrics import Metric
import tensorflow.keras.backend as K

# -------------------------------
# Configuración de advertencias
# -------------------------------
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')
warnings.filterwarnings('ignore', category=UserWarning)

# %%
datos_pacientes = []
grd_pacientes = []
edad = []
sexo = []
archivo1 = open("dataset/dataset_elpino.csv", encoding="utf-8")
encabezado = archivo1.readline().strip().split(";")
campos = []
df_visual = pd.read_csv("dataset/dataset_elpino.csv", sep= ';')
df_visual
# Out:
#                              Diag 01 Principal (cod+des)  \
# 0                A41.8 - Otras septicemias especificadas
# 1                   U07.1 - COVID-19, virus identificado
# 2      K56.5 - Adherencias [bridas] intestinales con ...
# 3      K76.8 - Otras enfermedades especificadas del h...
# 4      T81.0 - Hemorragia y hematoma que complican un...
# ...                                                  ...
# 14556  E10.1 - Diabetes mellitus tipo 1 con cetoacidosis
# 14557  S09.9 - Traumatismo de la cabeza, no especificado
# 14558                                     K92.1 - Melena
# 14559                     E78.1 - Hipergliceridemia pura
# 14560  S06.51 - Hemorragia subdural traumática, con h...
#
#                             Diag 02 Secundario (cod+des)  \
# 0         B37.6 - Endocarditis debida a candida (I39.8*)
# 1                  J12.8 - Neumonía debida a otros virus
# 2                                  R57.2 - Shock séptico
# 3                                  K66.1 - Hemoperitoneo
# 4      Y83.2 - Operación quirúrgica con anastomosis, ...
# ...                                                  ...
# 14556                      J45.9 - Asma, no especificada
# 14557  W18.24 - Otras caídas en el mismo nivel, escue...
# 14558             I10 - Hipertensión esencial (primaria)
# 14559             I10 - Hipertensión esencial (primaria)
# 14560  S06.21 - Traumatismo cerebral difuso, con heri...
#
#                             Diag 03 Secundario (cod+des)  \
# 0      I39.8 - Endocarditis, válvula no especificada,...
# 1                                         R06.0 - Disnea
# 2                            R57.1 - Choque hipovolémico
# 3            N18.5 - Enfermedad renal crónica, estadio 5
# 4                   S31.1 - Herida de la pared abdominal
# ...                                                  ...
# 14556  F10.2 - Trastornos mentales y del comportamien...
# 14557                            R55 - Síncope y colapso
# 14558  E11.9 - Diabetes mellitus tipo 2 sin complicac...
# 14559  Z92.2 - Historia personal de uso (presente) de...
# 14560  W18.09 - Otras caídas en el mismo nivel, vivie...
#
#                             Diag 04 Secundario (cod+des)  \
# 0                N10 - Nefritis tubulointersticial aguda
# 1                                              R05 - Tos
# 2      J80 - Síndrome de dificultad respiratoria del ...
# 3                 D64.9 - Anemia de tipo no especificado
# 4      S36.80 - Traumatismo de otros órganos intraabd...
# ...                                                  ...
# 14556  F17.2 - Trastornos mentales y del comportamien...
# 14557                                                  -
# 14558    I50.9 - Insuficiencia cardíaca, no especificada
# 14559                                                  -
# 14560  J69.0 - Neumonitis debida a aspiración de alim...
#
#                             Diag 05 Secundario (cod+des)  \
# 0      B96.1 - Klebsiella pneumoniae [K. pneumoniae] ...
# 1                        R50.9 - Fiebre, no especificada
# 2                              Y95 - Afección nosocomial
# 3                                 E87.5 - Hiperpotasemia
# 4      W31.62 - Contacto traumático con otras maquina...
# ...                                                  ...
# 14556  Z91.1 - Historia personal de incumplimiento de...
# 14557                                                  -
# 14558  K25.9 - Úlcera gástrica, no especificada como ...
# 14559                                                  -
# 14560               D29.1 - Tumor benigno de la próstata
#
#                             Diag 06 Secundario (cod+des)  \
# 0      L89.9 - Úlcera de decúbito y area de presión n...
# 1                                    Z29.0 - Aislamiento
# 2        J15.0 - Neumonía debida a Klebsiella pneumoniae
# 3                                       E87.2 - Acidosis
# 4      J96.09 - Insuficiencia respiratoria aguda, Tip...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558               M16.9 - Coxartrosis, no especificada
# 14559                                                  -
# 14560  Z59.0 - Problemas relacionados con la falta de...
#
#                             Diag 07 Secundario (cod+des)  \
# 0      L08.9 - Infección local de la piel y del tejid...
# 1                          Z01.7 - Examen de laboratorio
# 2      U82.2 - Resistencia a Betalactamasas de amplio...
# 3                                   J81 - Edema pulmonar
# 4        J15.0 - Neumonía debida a Klebsiella pneumoniae
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                            G47.3 - Apnea del sueño
# 14559                                                  -
# 14560            Z02.7 - Extensión de certificado médico
#
#                             Diag 08 Secundario (cod+des)  \
# 0      B96.2 - Escherichia coli [E. coli] como causa ...
# 1      J96.00 - Insuficiencia respiratoria aguda, Tip...
# 2      B95.6 - Staphylococcus aureus como causa de en...
# 3            N17.8 - Otras insuficiencias renales agudas
# 4      U82.2 - Resistencia a Betalactamasas de amplio...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558  Z99.8 - Dependencia de otras máquinas y dispos...
# 14559                                                  -
# 14560                                                  -
#
#                             Diag 09 Secundario (cod+des)  \
# 0      A41.5 - Sepsis por otros organnismos Gram nega...
# 1                                      J94.2 - Hemotórax
# 2      B96.8 - Otros agentes bacterianos especificado...
# 3      J44.9 - Enfermedad pulmonar obstructiva crónic...
# 4                   U07.1 - COVID-19, virus identificado
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560                                                  -
#
#                             Diag 10 Secundario (cod+des)  ...  \
# 0                           J86.9 - Piotórax sin fístula  ...
# 1                  J92.9 - Paquipleuritis sin asbestosis  ...
# 2                           B37.1 - Candidiasis pulmonar  ...
# 3                 R41.0 - Desorientación no especificada  ...
# 4      N39.0 - Infección de vías urinarias, sitio no ...  ...
# ...                                                  ...  ...
# 14556                                                  -  ...
# 14557                                                  -  ...
# 14558                                                  -  ...
# 14559                                                  -  ...
# 14560                                                  -  ...
#
#                    Proced 24 Secundario (cod+des)  \
# 0                             99.84 - AISLAMIENTO
# 1        91.62 - EXAMEN MICROSCOPICO PIEL.CULTIVO
# 2                             99.84 - AISLAMIENTO
# 3             57.94 - SONDAJE URINARIO PERMANENTE
# 4      90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# ...                                           ...
# 14556                                           -
# 14557                                           -
# 14558                                           -
# 14559                                           -
# 14560                     89.66 - GASOMETRIA VENA
#
#                           Proced 25 Secundario (cod+des)  \
# 0                                88.72 - ECOCARDIOGRAFIA
# 1      90.43 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTI...
# 2      91.73 - EXAMEN MICROSCOPICO HERIDA OPERATORIA....
# 3                           00.13 - INYECCION NESIRITIDE
# 4      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560                            89.66 - GASOMETRIA VENA
#
#                           Proced 26 Secundario (cod+des)  \
# 0       90.42 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTIVO
# 1      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2      90.53 - EXAMEN MICROSCOPICO SANGRE.CULTIVO Y S...
# 3                      00.17 - INFUSON AGENTE VASOPRESOR
# 4      91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560               90.39 - EXAMEN MICROSCOPICO ORL.OTRO
#
#                           Proced 27 Secundario (cod+des)  \
# 0             90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 1             90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
# 2                       99.26 - INYECCION TRANQUILIZANTE
# 3               99.04 - TRANSFUSION CONCENTRADO HEMATIES
# 4      93.90 - RESPIRACION PRESION POSITIVA CONTINUA ...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560   90.42 - EXAMEN MICROSCOPICO RESPIRATORIO.CULTIVO
#
#                           Proced 28 Secundario (cod+des)  \
# 0      91.39 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1      91.32 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 2      89.39 - OTRAS MEDICIONES Y EXAMENES NO QUIRURG...
# 3                          99.18 - INYECCION ELECTROLITO
# 4      99.15 - INFUSION PARENTERAL SUSTANCIA NUTRITIV...
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560         90.52 - EXAMEN MICROSCOPICO SANGRE.CULTIVO
#
#                           Proced 29 Secundario (cod+des)  \
# 0      91.33 - EXAMEN MICROSCOPICO URINARIO INFERIOR....
# 1                         96.59 - IRRIGACION HERIDA OTRA
# 2                                89.66 - GASOMETRIA VENA
# 3                          99.21 - INYECCION ANTIBIOTICO
# 4                         96.59 - IRRIGACION HERIDA OTRA
# ...                                                  ...
# 14556                                                  -
# 14557                                                  -
# 14558                                                  -
# 14559                                                  -
# 14560            90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO
#
#                           Proced 30 Secundario (cod+des) Edad en años  \
# 0          87.03 - TOMOGRAFIA AXIAL COMPUTERIZADA CABEZA           40
# 1      90.99 - EXAMEN MICROSCOPICO DIGESTIVO INFERIOR...           53
# 2                             89.65 - GASOMETRIA ARTERIA           65
# 3                            99.23 - INYECCION ESTEROIDE           61
# 4               45.13 - ESOFAGOGASTRODUODENOSCOPIA [EGD]           30
# ...                                                  ...          ...
# 14556                                                  -           26
# 14557                                                  -           10
# 14558                                                  -           58
# 14559                                                  -           47
# 14560            90.59 - EXAMEN MICROSCOPICO SANGRE.OTRO           73
#
#       Sexo (Desc)                                                GRD
# 0          Hombre                       184103 - MH SEPTICEMIA W/MCC
# 1          Hombre  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 2          Hombre  041013 - PH ECMO VENTILACIÓN MECÁNICA PROLONGA...
# 3          Hombre  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# 4          Hombre  041023 - PH VENTILACIÓN MECÁNICA PROLONGADA SI...
# ...           ...                                                ...
# 14556       Mujer  104101 - MH DIABETES Y ENFERMEDADES METABÓLICA...
# 14557      Hombre              014242 - MH TRAUMATISMO CEFÁLICO W/CC
# 14558      Hombre  064182 - MH OTROS DIAGNÓSTICOS SOBRE APARATO D...
# 14559      Hombre      104121 - MH ERRORES CONGÉNITOS DE METABOLISMO
# 14560      Hombre  041203 - PH PROCEDIMIENTOS NO COMPLEJOS SOBRE ...
#
# [14561 rows x 68 columns]

# %%
## Resuen Estadistico descriptivo 

import matplotlib.pyplot as plt
import seaborn as sns

# Resumen estadístico
print(df_visual.describe())
num_cols = df_visual.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(7, 7))
for i, col in enumerate(num_cols, 1):
    plt.subplot(len(num_cols)//3 + 1, 3, i)
    sns.histplot(df_visual[col], kde=True, bins=30)
    plt.title(f'Distribución de {col}')
    plt.tight_layout()

plt.show()
# Out:
#        Edad en años
# count  14561.000000
# mean      39.426550
# std       24.681545
# min        0.000000
# 25%       23.000000
# 50%       36.000000
# 75%       60.000000
# max      121.000000

# %%
for columna in encabezado:
    columna = columna.split("-")[0].strip()
    if columna.startswith("Diag") or columna.startswith("Proc"):
        columna = columna.split(" ")
        columna = columna[0] + columna[1]
    campos.append(columna)

for linea in archivo1:
    datos_ficha = []
    linea = linea.strip().split(";")
    for i in range(len(linea)):
        dato = linea[i].split("-")[0].strip()
        if i == 67:  
            grd = dato
            grd_pacientes.append(grd)
        elif i == 66:  
            sexo.append(1 if dato == "Mujer" else 0)
        elif i == 65:  
            edad.append(int(dato))
        else:
            datos_ficha.append(dato)
    datos_pacientes.append(datos_ficha)

# %%
df = pd.DataFrame(datos_pacientes, columns=campos[:-3])
df["GRD"] = grd_pacientes
df
# Out:
#       ﻿Diag 01 Principal (cod+des)  Diag02  Diag03  Diag04  Diag05  Diag06  \
# 0                            A41.8   B37.6   I39.8     N10   B96.1   L89.9
# 1                            U07.1   J12.8   R06.0     R05   R50.9   Z29.0
# 2                            K56.5   R57.2   R57.1     J80     Y95   J15.0
# 3                            K76.8   K66.1   N18.5   D64.9   E87.5   E87.2
# 4                            T81.0   Y83.2   S31.1  S36.80  W31.62  J96.09
# ...                            ...     ...     ...     ...     ...     ...
# 14556                        E10.1   J45.9   F10.2   F17.2   Z91.1
# 14557                        S09.9  W18.24     R55
# 14558                        K92.1     I10   E11.9   I50.9   K25.9   M16.9
# 14559                        E78.1     I10   Z92.2
# 14560                       S06.51  S06.21  W18.09   J69.0   D29.1   Z59.0
#
#       Diag07  Diag08 Diag09 Diag10  ... Proced22 Proced23 Proced24 Proced25  \
# 0      L08.9   B96.2  A41.5  J86.9  ...    99.04    90.39    99.84    88.72
# 1      Z01.7  J96.00  J94.2  J92.9  ...    91.69    87.44    91.62    90.43
# 2      U82.2   B95.6  B96.8  B37.1  ...    91.33    90.39    99.84    91.73
# 3        J81   N17.8  J44.9  R41.0  ...    96.59    94.19    57.94    00.13
# 4      J15.0   U82.2  U07.1  N39.0  ...    99.21    99.29    90.52    91.39
# ...      ...     ...    ...    ...  ...      ...      ...      ...      ...
# 14556                               ...
# 14557                               ...
# 14558  G47.3   Z99.8                ...
# 14559                               ...
# 14560  Z02.7                        ...    93.96    93.99    89.66    89.66
#
#       Proced26 Proced27 Proced28 Proced29 Proced30     GRD
# 0        90.42    90.52    91.39    91.33    87.03  184103
# 1        91.39    90.52    91.32    96.59    90.99  041013
# 2        90.53    99.26    89.39    89.66    89.65  041013
# 3        00.17    99.04    99.18    99.21    99.23  041023
# 4        91.32    93.90    99.15    96.59    45.13  041023
# ...        ...      ...      ...      ...      ...     ...
# 14556                                               104101
# 14557                                               014242
# 14558                                               064182
# 14559                                               104121
# 14560    90.39    90.42    90.52    90.59    90.59  041203
#
# [14561 rows x 66 columns]

# %%
filtro = (df["GRD"]=='146101') | (df["GRD"]=='146102') | (df["GRD"]=='146103')
datos_filtrados = df[filtro]

# %%
print("Nombres de columnas en el DataFrame:")
print(df.columns.tolist()[:10])
# Out:
# Nombres de columnas en el DataFrame:
# ['\ufeffDiag 01 Principal (cod+des)', 'Diag02', 'Diag03', 'Diag04', 'Diag05', 'Diag06', 'Diag07', 'Diag08', 'Diag09', 'Diag10']

# %%
columnas_diagnosticos = [col for col in df.columns if 'Diag' in col]
columnas_procedimientos = [col for col in df.columns if 'Proced' in col]

# %%
diagnosticos = {}
procedimientos = {}

for i, fila in datos_filtrados.iterrows():
    # Procesamiento de diagnósticos
    for columna in columnas_diagnosticos:
        if fila[columna] not in diagnosticos:
            diagnosticos[fila[columna]] = 1
        else:
            diagnosticos[fila[columna]] += 1
    
    for columna in columnas_procedimientos:
        if fila[columna] not in procedimientos:
            procedimientos[fila[columna]] = 1
        else:
            procedimientos[fila[columna]] += 1

# %%
# Crear vocabulario
codigos_diagnosticos = list(diagnosticos.keys())
codigos_procedimientos = list(procedimientos.keys())
tamano_vocabulario = len(codigos_diagnosticos) + len(codigos_procedimientos) + 1

print("Diagnósticos únicos:", len(codigos_diagnosticos))
print("Procedimientos únicos:", len(codigos_procedimientos))
print("Tamaño del vocabulario:", tamano_vocabulario)
# Out:
# Diagnósticos únicos: 377
# Procedimientos únicos: 155
# Tamaño del vocabulario: 533

# %%
# Tokenización de los datos
fichas_numericas = []
columnas_diagnosticos = [col for col in datos_filtrados.columns if 'Diag' in col]
columnas_procedimientos = [col for col in datos_filtrados.columns if 'Proced' in col]

for i, fila in datos_filtrados.iterrows():
    ficha_numerica = []
    # Procesar diagnósticos
    for columna in columnas_diagnosticos:
        ficha_numerica.append(1 + codigos_diagnosticos.index(fila[columna]))
    for columna in columnas_procedimientos:
        ficha_numerica.append(1 + len(codigos_diagnosticos) + 
                            codigos_procedimientos.index(fila[columna]))
    fichas_numericas.append(ficha_numerica)

# %% [markdown]
# ### Entrenar Modelo

# %%
# Preparación final de los datos
X = pad_sequences(fichas_numericas)
Y = datos_filtrados["GRD"].apply(lambda x: int(x)).to_numpy()

# %%
# Codificación de las etiquetas
codificador = LabelEncoder()
Y = codificador.fit_transform(Y)
Y = Y.reshape(-1, 1)
codificador_onehot = OneHotEncoder()
Y = codificador_onehot.fit_transform(Y).todense()

# %%
# División de datos en entrenamiento y validación
x_train, x_val, y_train, y_val = train_test_split(X, Y, random_state=0)

# %%
# Creación del modelo LSTM
modelo_lstm = Sequential()
modelo_lstm.add(Embedding(input_dim=tamano_vocabulario, output_dim=64))
modelo_lstm.add(LSTM(32))
modelo_lstm.add(Dense(Y.shape[1], activation="softmax"))

modelo_lstm.compile(optimizer="Adam",
                   loss="categorical_crossentropy",
                   metrics=["acc"])

# %%
# Configuración de callbacks para el entrenamiento
tag = "lstm_" + datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = "logs/fit/" + tag
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
earlystopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_acc", 
                                                         patience=4,
                                                         restore_best_weights=True)

# %%
# Entrenamiento del modelo
historia_lstm = modelo_lstm.fit(x_train, y_train, 
                              validation_data=(x_val, y_val),
                              batch_size=32, epochs=16, verbose=2,
                              callbacks=[tensorboard_callback, earlystopping_callback])
# Out:
# Epoch 1/16
# 29/29 - 3s - 88ms/step - acc: 0.6656 - loss: 0.8859 - val_acc: 0.6689 - val_loss: 0.8725
# Epoch 2/16
# 29/29 - 0s - 15ms/step - acc: 0.6689 - loss: 0.8545 - val_acc: 0.6689 - val_loss: 0.8607
# Epoch 3/16
# 29/29 - 0s - 15ms/step - acc: 0.6689 - loss: 0.8502 - val_acc: 0.6689 - val_loss: 0.8581
# Epoch 4/16
# 29/29 - 0s - 15ms/step - acc: 0.6699 - loss: 0.8495 - val_acc: 0.6721 - val_loss: 0.8316
# Epoch 5/16
# 29/29 - 0s - 15ms/step - acc: 0.6678 - loss: 0.7843 - val_acc: 0.6984 - val_loss: 0.6740
# Epoch 6/16
# 29/29 - 0s - 15ms/step - acc: 0.6951 - loss: 0.7307 - val_acc: 0.7672 - val_loss: 0.6858
# Epoch 7/16
# 29/29 - 0s - 15ms/step - acc: 0.7519 - loss: 0.5996 - val_acc: 0.7574 - val_loss: 0.5466
# Epoch 8/16
# 29/29 - 0s - 15ms/step - acc: 0.7945 - loss: 0.5136 - val_acc: 0.8197 - val_loss: 0.4716
# Epoch 9/16
# 29/29 - 0s - 15ms/step - acc: 0.8426 - loss: 0.4230 - val_acc: 0.7803 - val_loss: 0.4956
# Epoch 10/16
# 29/29 - 0s - 15ms/step - acc: 0.8710 - loss: 0.3604 - val_acc: 0.8623 - val_loss: 0.3505
# Epoch 11/16
# 29/29 - 0s - 16ms/step - acc: 0.8907 - loss: 0.3156 - val_acc: 0.8230 - val_loss: 0.4194
# Epoch 12/16
# 29/29 - 0s - 15ms/step - acc: 0.8732 - loss: 0.3765 - val_acc: 0.8230 - val_loss: 0.4265
# Epoch 13/16
# 29/29 - 0s - 16ms/step - acc: 0.8863 - loss: 0.3180 - val_acc: 0.8426 - val_loss: 0.3825
# Epoch 14/16
# 29/29 - 0s - 16ms/step - acc: 0.9235 - loss: 0.2662 - val_acc: 0.9115 - val_loss: 0.3207
# Epoch 15/16
# 29/29 - 0s - 15ms/step - acc: 0.9213 - loss: 0.2576 - val_acc: 0.8984 - val_loss: 0.2988
# Epoch 16/16
# 29/29 - 0s - 16ms/step - acc: 0.9257 - loss: 0.2462 - val_acc: 0.9049 - val_loss: 0.2973

# %%
# Guardar el modelo
modelo_lstm.save(f'modelos/modelo_{tag}.keras')

# %%
# Predicciones y evaluación
y_pred_probs = modelo_lstm.predict(x_val)
y_pred = np.argmax(y_pred_probs, axis=1)
y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Visualización de resultados
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(20, 4)

# Matriz de confusión
matriz_ltsm = confusion_matrix(y_val_1d, y_pred)
ax = axes[0]
sns.heatmap(matriz_ltsm, annot=True, ax=ax, cmap="Blues", fmt="d")
ax.set_title("Rec=" + str(round(recall_score(y_val_1d, y_pred, average="macro"), 2)) +
             " Acc=" + str(round(accuracy_score(y_val_1d, y_pred), 2)) +
             " F1=" + str(round(f1_score(y_val_1d, y_pred, average="macro"), 2)) +
             " Pre=" + str(round(precision_score(y_val_1d, y_pred, average="macro"), 2)))
axes[0].set_xlabel('Predicción')
axes[0].set_ylabel('Real')

# Curvas ROC para cada clase
fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), 
                                 np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title(f'Curva ROC Clase {i}, AUC={round(roc_auc[i],2)}')

plt.tight_layout()
plt.show()

# %%
for i in range(3):
    print(f"Clase {i}:")
    print("ACC=", round(accuracy_score(np.squeeze(np.asarray(y_val[:,i])), 
                                     y_pred_probs[:,i] >= 0.5), 2),
          "PRE=", round(precision_score(np.squeeze(np.asarray(y_val[:,i])), 
                                      y_pred_probs[:,i] >= 0.5), 2),
          "REC=", round(recall_score(np.squeeze(np.asarray(y_val[:,i])), 
                                   y_pred_probs[:,i] >= 0.5), 2))
# Out:
# Clase 0:
# ACC= 0.92 PRE= 0.96 REC= 0.92
# Clase 1:
# ACC= 0.91 PRE= 0.7 REC= 0.81
# Clase 2:
# ACC= 0.97 PRE= 0.9 REC= 0.92

# %% [markdown]
# ### Modelo 2

# %%
modelo_emb = Sequential()
modelo_emb.add(Embedding(input_dim=tamano_vocabulario, output_dim=64))
modelo_emb.add(GlobalAveragePooling1D())
modelo_emb.add(Dense(64, activation='relu'))
modelo_emb.add(Dense(Y.shape[1], activation="softmax"))
modelo_emb.compile(optimizer="Adam",
                  loss="categorical_crossentropy",
                  metrics=["acc"])

# %%
tag = "emb_" + datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = "logs/fit/" + tag
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
earlystopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_acc",
                                                         patience=4,
                                                         restore_best_weights=True)

# %%
#Guardar el modelo
modelo_emb.save(f'modelos/modelo_{tag}.keras')
# Out:
# c:\Users\fiton\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:107: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   return saving_lib.save_model(model, filepath)

# %%
# Predicciones y evaluación
y_pred_probs = modelo_emb.predict(x_val)
y_pred = np.argmax(y_pred_probs, axis=1)
y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Visualización de resultados
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(20, 4)

# Matriz de confusión
matriz = confusion_matrix(y_val_1d, y_pred)
ax = axes[0]
sns.heatmap(matriz, annot=True, ax=ax, cmap="Blues", fmt="d")
ax.set_title("Rec=" + str(round(recall_score(y_val_1d, y_pred, average="macro"), 2)) +
             " Acc=" + str(round(accuracy_score(y_val_1d, y_pred), 2)) +
             " F1=" + str(round(f1_score(y_val_1d, y_pred, average="macro"), 2)) +
             " Pre=" + str(round(precision_score(y_val_1d, y_pred, average="macro"), 2)))
axes[0].set_xlabel('Predicción')
axes[0].set_ylabel('Real')

# Curvas ROC para cada clase
fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), 
                                 np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title(f'Curva ROC Clase {i}, AUC={round(roc_auc[i],2)}')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\fiton\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
for i in range(3):
    print(f"Clase {i}:")
    print("ACC=", round(accuracy_score(np.squeeze(np.asarray(y_val[:,i])), 
                                     y_pred_probs[:,i] >= 0.5), 2),
          "PRE=", round(precision_score(np.squeeze(np.asarray(y_val[:,i])), 
                                      y_pred_probs[:,i] >= 0.5), 2),
          "REC=", round(recall_score(np.squeeze(np.asarray(y_val[:,i])), 
                                   y_pred_probs[:,i] >= 0.5), 2))
# Out:
# Clase 0:
# ACC= 0.33 PRE= 0.0 REC= 0.0
# Clase 1:
# ACC= 0.83 PRE= 0.0 REC= 0.0
# Clase 2:
# ACC= 0.84 PRE= 0.0 REC= 0.0
# c:\Users\fiton\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\fiton\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\fiton\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Modelo 3

# %%
#modelo transformer
inputs = Input(shape=(X.shape[1],))
embedding = Embedding(input_dim=tamano_vocabulario, output_dim=64)(inputs)

# %%
# Bloque de atención
attention = MultiHeadAttention(num_heads=2, key_dim=32)(embedding, embedding)
attention = Dropout(0.1)(attention)
attention = LayerNormalization(epsilon=1e-6)(attention)

# %%
# Feed-forward network
ff = Dense(64, activation="relu")(attention)
ff = Dense(64)(ff)
ff = Dropout(0.1)(ff)
ff = LayerNormalization(epsilon=1e-6)(ff)

# %%
# Capa final
pooling = GlobalAveragePooling1D()(ff)
outputs = Dense(Y.shape[1], activation="softmax")(pooling)

# %%
# Construimos el modelo
modelo_transformer = Model(inputs=inputs, outputs=outputs)

# %%
# Compilación
modelo_transformer.compile(optimizer="Adam",
                         loss="categorical_crossentropy",
                         metrics=["acc"])

# %%
# Configuración del entrenamiento
tag = "transformer_" + datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = "logs/fit/" + tag

# Callbacks para el entrenamiento
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
earlystopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_acc",
                                                         patience=4,
                                                         restore_best_weights=True)

# %%
# Entrenamiento del modelo
historia_transformer = modelo_transformer.fit(x_train, y_train,
                                           validation_data=(x_val, y_val),
                                           batch_size=32, epochs=16, verbose=2,
                                           callbacks=[tensorboard_callback, 
                                                    earlystopping_callback])
# Out:
# Epoch 1/16
# 29/29 - 3s - 117ms/step - acc: 0.6328 - loss: 0.9504 - val_acc: 0.6689 - val_loss: 0.8704
# Epoch 2/16
# 29/29 - 0s - 13ms/step - acc: 0.6656 - loss: 0.8630 - val_acc: 0.6689 - val_loss: 0.8662
# Epoch 3/16
# 29/29 - 0s - 14ms/step - acc: 0.6656 - loss: 0.8589 - val_acc: 0.6689 - val_loss: 0.8716
# Epoch 4/16
# 29/29 - 0s - 14ms/step - acc: 0.6656 - loss: 0.8474 - val_acc: 0.6689 - val_loss: 0.8072
# Epoch 5/16
# 29/29 - 0s - 14ms/step - acc: 0.7093 - loss: 0.6972 - val_acc: 0.8230 - val_loss: 0.4304
# Epoch 6/16
# 29/29 - 0s - 14ms/step - acc: 0.8230 - loss: 0.4434 - val_acc: 0.8754 - val_loss: 0.3286
# Epoch 7/16
# 29/29 - 0s - 14ms/step - acc: 0.9202 - loss: 0.2519 - val_acc: 0.8033 - val_loss: 0.4971
# Epoch 8/16
# 29/29 - 0s - 14ms/step - acc: 0.9279 - loss: 0.2072 - val_acc: 0.9148 - val_loss: 0.2707
# Epoch 9/16
# 29/29 - 0s - 14ms/step - acc: 0.9454 - loss: 0.1541 - val_acc: 0.9049 - val_loss: 0.3527
# Epoch 10/16
# 29/29 - 0s - 13ms/step - acc: 0.9475 - loss: 0.1501 - val_acc: 0.8689 - val_loss: 0.4110
# Epoch 11/16
# 29/29 - 0s - 14ms/step - acc: 0.9530 - loss: 0.1387 - val_acc: 0.9180 - val_loss: 0.3533
# Epoch 12/16
# 29/29 - 0s - 13ms/step - acc: 0.9552 - loss: 0.1281 - val_acc: 0.8820 - val_loss: 0.4164
# Epoch 13/16
# 29/29 - 0s - 13ms/step - acc: 0.9497 - loss: 0.1546 - val_acc: 0.9016 - val_loss: 0.3651
# Epoch 14/16
# 29/29 - 0s - 13ms/step - acc: 0.9552 - loss: 0.1092 - val_acc: 0.8951 - val_loss: 0.4013
# Epoch 15/16
# 29/29 - 0s - 13ms/step - acc: 0.9650 - loss: 0.0990 - val_acc: 0.8951 - val_loss: 0.4740

# %%
# Guardamos el modelo entrenado
modelo_transformer.save(f'modelos/modelo_{tag}.keras')

# %%
# Evaluación del modelo
y_pred_probs = modelo_transformer.predict(x_val)
y_pred = np.argmax(y_pred_probs, axis=1)
y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# Visualización de resultados: creamos una figura con 4 subplots
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(20, 4)

# Matriz de confusión
matriz = confusion_matrix(y_val_1d, y_pred)
ax = axes[0]
sns.heatmap(matriz, annot=True, ax=ax, cmap="Blues", fmt="d")
ax.set_title("Rec=" + str(round(recall_score(y_val_1d, y_pred, average="macro"), 2)) +
            " Acc=" + str(round(accuracy_score(y_val_1d, y_pred), 2)) +
            " F1=" + str(round(f1_score(y_val_1d, y_pred, average="macro"), 2)) +
            " Pre=" + str(round(precision_score(y_val_1d, y_pred, average="macro"), 2)))
axes[0].set_xlabel('Predicción')
axes[0].set_ylabel('Real')

# Curvas ROC 
fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):
   fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), 
                                np.asarray(y_pred_probs[:, i]))
   roc_auc[i] = auc(fpr[i], tpr[i])
   
   axes[i+1].plot(fpr[i], tpr[i])
   axes[i+1].plot([0, 1], [0, 1], 'k--')
   axes[i+1].set_xlabel('FPR')
   axes[i+1].set_ylabel('TPR')
   axes[i+1].set_title(f'Curva ROC Clase {i}, AUC={round(roc_auc[i],2)}')

plt.tight_layout()
plt.show()

# %%
# Imprimimos las métricas
for i in range(3):
   print(f"Clase {i}:")
   print("ACC=", round(accuracy_score(np.squeeze(np.asarray(y_val[:,i])), 
                                    y_pred_probs[:,i] >= 0.5), 2),
         "PRE=", round(precision_score(np.squeeze(np.asarray(y_val[:,i])), 
                                     y_pred_probs[:,i] >= 0.5), 2),
         "REC=", round(recall_score(np.squeeze(np.asarray(y_val[:,i])), 
                                  y_pred_probs[:,i] >= 0.5), 2))
# Out:
# Clase 0:
# ACC= 0.93 PRE= 0.96 REC= 0.94
# Clase 1:
# ACC= 0.92 PRE= 0.76 REC= 0.81
# Clase 2:
# ACC= 0.97 PRE= 0.9 REC= 0.94

# %% [markdown]
# #### Busqueda de mejores parametros gridsearch

# %%
x_train, x_val, y_train, y_val = train_test_split(X, Y, random_state=0)

# %%
def entrenar_y_evaluar_modelo(parametros):
    modelo = crear_modelo_lstm(
        tamano_vocabulario=tamano_vocabulario,
        output_dim=parametros['output_dim'],
        lstm_units=parametros['lstm_units'],
        optimizer=parametros['optimizer'],
        dropout=parametros['dropout']
    )
    historia = modelo.fit(
        x_train, y_train,
        batch_size=parametros['batch_size'],
        epochs=parametros['epochs'],
        validation_data=(x_val, y_val),
        verbose=0
    )
    y_pred_probs = modelo.predict(x_val, verbose=0)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_val_1d = np.asarray(np.argmax(y_val, axis=1))  
    y_pred = np.asarray(y_pred)  
    acc = accuracy_score(y_val_1d, y_pred)
    return acc, modelo, historia

# %%
# Definir los parámetros a buscar
parametros = {
    'output_dim': [32, 64, 128],
    'lstm_units': [32, 64, 128],
    'optimizer': ['adam', 'rmsprop'],
    'dropout': [0.0, 0.2, 0.5],
    'batch_size': [32, 64],
    'epochs': [10, 20]
}

# Generar todas las combinaciones
combinaciones = list(product(
    parametros['output_dim'],
    parametros['lstm_units'],
    parametros['optimizer'],
    parametros['dropout'],
    parametros['batch_size'],
    parametros['epochs']
))

# Convertir combinaciones a un formato legible
combinaciones = [
    {
        'output_dim': c[0],
        'lstm_units': c[1],
        'optimizer': c[2],
        'dropout': c[3],
        'batch_size': c[4],
        'epochs': c[5]
    }
    for c in combinaciones
]

# %%
resultados = []

for i, params in enumerate(combinaciones):
    print(f"Entrenando modelo {i+1}/{len(combinaciones)} con parámetros: {params}")
    acc, modelo, historia = entrenar_y_evaluar_modelo(params)
    resultados.append({'params': params, 'accuracy': acc})
    print(f"Exactitud obtenida: {acc:.4f}")
# Out:
# Entrenando modelo 1/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8295
# Entrenando modelo 2/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8197
# Entrenando modelo 3/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7934
# Entrenando modelo 4/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8262
# Entrenando modelo 5/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8656
# Entrenando modelo 6/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7836
# Entrenando modelo 7/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6885
# Entrenando modelo 8/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 9/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 10/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 11/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7377
# Entrenando modelo 12/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7869
# Entrenando modelo 13/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8066
# Entrenando modelo 14/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8590
# Entrenando modelo 15/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.3934
# Entrenando modelo 16/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7574
# Entrenando modelo 17/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7967
# Entrenando modelo 18/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7967
# Entrenando modelo 19/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7049
# Entrenando modelo 20/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7574
# Entrenando modelo 21/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7541
# Entrenando modelo 22/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6033
# Entrenando modelo 23/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7869
# Entrenando modelo 24/216 con parámetros: {'output_dim': 32, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7869
# Entrenando modelo 25/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7344
# Entrenando modelo 26/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7705
# Entrenando modelo 27/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 28/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8557
# Entrenando modelo 29/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7967
# Entrenando modelo 30/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 31/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7311
# Entrenando modelo 32/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6984
# Entrenando modelo 33/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8066
# Entrenando modelo 34/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 35/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8066
# Entrenando modelo 36/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8525
# Entrenando modelo 37/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7967
# Entrenando modelo 38/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8426
# Entrenando modelo 39/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7016
# Entrenando modelo 40/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7705
# Entrenando modelo 41/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7869
# Entrenando modelo 42/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.9115
# Entrenando modelo 43/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7902
# Entrenando modelo 44/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8426
# Entrenando modelo 45/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8098
# Entrenando modelo 46/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8459
# Entrenando modelo 47/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7508
# Entrenando modelo 48/216 con parámetros: {'output_dim': 32, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8295
# Entrenando modelo 49/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6262
# Entrenando modelo 50/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 51/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7148
# Entrenando modelo 52/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7738
# Entrenando modelo 53/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 54/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 55/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8098
# Entrenando modelo 56/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8656
# Entrenando modelo 57/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 58/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7508
# Entrenando modelo 59/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7639
# Entrenando modelo 60/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8197
# Entrenando modelo 61/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8230
# Entrenando modelo 62/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8656
# Entrenando modelo 63/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6754
# Entrenando modelo 64/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8033
# Entrenando modelo 65/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6557
# Entrenando modelo 66/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 67/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7016
# Entrenando modelo 68/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7869
# Entrenando modelo 69/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7770
# Entrenando modelo 70/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 71/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6918
# Entrenando modelo 72/216 con parámetros: {'output_dim': 32, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7836
# Entrenando modelo 73/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7672
# Entrenando modelo 74/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.9016
# Entrenando modelo 75/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8098
# Entrenando modelo 76/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8131
# Entrenando modelo 77/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8033
# Entrenando modelo 78/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8098
# Entrenando modelo 79/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6984
# Entrenando modelo 80/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8984
# Entrenando modelo 81/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7836
# Entrenando modelo 82/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7541
# Entrenando modelo 83/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7803
# Entrenando modelo 84/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7836
# Entrenando modelo 85/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7016
# Entrenando modelo 86/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8918
# Entrenando modelo 87/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7246
# Entrenando modelo 88/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7967
# Entrenando modelo 89/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 90/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8459
# Entrenando modelo 91/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6885
# Entrenando modelo 92/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7869
# Entrenando modelo 93/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 94/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8033
# Entrenando modelo 95/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7934
# Entrenando modelo 96/216 con parámetros: {'output_dim': 64, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7836
# Entrenando modelo 97/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8164
# Entrenando modelo 98/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7443
# Entrenando modelo 99/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7836
# Entrenando modelo 100/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8230
# Entrenando modelo 101/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 102/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 103/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7934
# Entrenando modelo 104/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8623
# Entrenando modelo 105/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 106/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 107/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7738
# Entrenando modelo 108/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 109/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7246
# Entrenando modelo 110/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.5311
# Entrenando modelo 111/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7180
# Entrenando modelo 112/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8033
# Entrenando modelo 113/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7115
# Entrenando modelo 114/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.9016
# Entrenando modelo 115/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7213
# Entrenando modelo 116/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7836
# Entrenando modelo 117/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 118/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 119/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7738
# Entrenando modelo 120/216 con parámetros: {'output_dim': 64, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7902
# Entrenando modelo 121/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 122/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7934
# Entrenando modelo 123/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7869
# Entrenando modelo 124/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8295
# Entrenando modelo 125/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7705
# Entrenando modelo 126/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 127/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 128/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6721
# Entrenando modelo 129/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 130/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7705
# Entrenando modelo 131/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 132/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 133/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 134/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8393
# Entrenando modelo 135/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7115
# Entrenando modelo 136/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 137/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7967
# Entrenando modelo 138/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 139/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7148
# Entrenando modelo 140/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8066
# Entrenando modelo 141/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6295
# Entrenando modelo 142/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8984
# Entrenando modelo 143/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7213
# Entrenando modelo 144/216 con parámetros: {'output_dim': 64, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7541
# Entrenando modelo 145/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8164
# Entrenando modelo 146/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7902
# Entrenando modelo 147/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7344
# Entrenando modelo 148/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8262
# Entrenando modelo 149/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8066
# Entrenando modelo 150/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6426
# Entrenando modelo 151/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7803
# Entrenando modelo 152/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8689
# Entrenando modelo 153/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 154/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8295
# Entrenando modelo 155/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8098
# Entrenando modelo 156/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7213
# Entrenando modelo 157/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8262
# Entrenando modelo 158/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.9049
# Entrenando modelo 159/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7246
# Entrenando modelo 160/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8033
# Entrenando modelo 161/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6918
# Entrenando modelo 162/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8721
# Entrenando modelo 163/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7311
# Entrenando modelo 164/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8230
# Entrenando modelo 165/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7902
# Entrenando modelo 166/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8164
# Entrenando modelo 167/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7213
# Entrenando modelo 168/216 con parámetros: {'output_dim': 128, 'lstm_units': 32, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8066
# Entrenando modelo 169/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7902
# Entrenando modelo 170/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 171/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7869
# Entrenando modelo 172/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 173/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 174/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8000
# Entrenando modelo 175/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 176/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 177/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 178/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 179/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8000
# Entrenando modelo 180/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 181/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7738
# Entrenando modelo 182/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8754
# Entrenando modelo 183/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6885
# Entrenando modelo 184/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7738
# Entrenando modelo 185/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.5016
# Entrenando modelo 186/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8590
# Entrenando modelo 187/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7082
# Entrenando modelo 188/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8098
# Entrenando modelo 189/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6951
# Entrenando modelo 190/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7967
# Entrenando modelo 191/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7279
# Entrenando modelo 192/216 con parámetros: {'output_dim': 128, 'lstm_units': 64, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6721
# Entrenando modelo 193/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 194/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7115
# Entrenando modelo 195/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 196/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 197/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 198/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 199/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6885
# Entrenando modelo 200/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7377
# Entrenando modelo 201/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.6689
# Entrenando modelo 202/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 203/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.8033
# Entrenando modelo 204/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'adam', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.6689
# Entrenando modelo 205/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7279
# Entrenando modelo 206/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.7902
# Entrenando modelo 207/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.7115
# Entrenando modelo 208/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.0, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7246
# Entrenando modelo 209/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7934
# Entrenando modelo 210/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8164
# Entrenando modelo 211/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6820
# Entrenando modelo 212/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.2, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.8033
# Entrenando modelo 213/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 10}
# Exactitud obtenida: 0.7934
# Entrenando modelo 214/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 32, 'epochs': 20}
# Exactitud obtenida: 0.8885
# Entrenando modelo 215/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 10}
# Exactitud obtenida: 0.6787
# Entrenando modelo 216/216 con parámetros: {'output_dim': 128, 'lstm_units': 128, 'optimizer': 'rmsprop', 'dropout': 0.5, 'batch_size': 64, 'epochs': 20}
# Exactitud obtenida: 0.7738

# %%
df_resultados = pd.DataFrame(resultados)
df_resultados = df_resultados.sort_values(by='accuracy', ascending=False)
print("Mejores parámetros encontrados:")
print(df_resultados.iloc[0])
# Out:
# Mejores parámetros encontrados:
# params      {'output_dim': 32, 'lstm_units': 64, 'optimize...
# accuracy                                             0.911475
# Name: 41, dtype: object

# %%
mejores_params = df_resultados.iloc[0]['params']
_, modelo_final, historia_final = entrenar_y_evaluar_modelo(mejores_params)
modelo_final.save("modelo_lstm_mejorado.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Visualización de la precisión, pérdida y curvas ROC
fig, axes = plt.subplots(1, 2, figsize=(20, 5))

# Pérdida durante el entrenamiento
axes[0].plot(historia_final.history['loss'], label='Pérdida de entrenamiento')
axes[0].plot(historia_final.history['val_loss'], label='Pérdida de validación')
axes[0].set_title('Pérdida durante el entrenamiento')
axes[0].set_xlabel('Épocas')
axes[0].set_ylabel('Pérdida')
axes[0].legend()

# Precisión durante el entrenamiento
axes[1].plot(historia_final.history['accuracy'], label='Precisión de entrenamiento')
axes[1].plot(historia_final.history['val_accuracy'], label='Precisión de validación')
axes[1].set_title('Precisión durante el entrenamiento')
axes[1].set_xlabel('Épocas')
axes[1].set_ylabel('Precisión')
axes[1].legend()

# %%
y_pred = modelo_final.predict(x_val)  
if y_pred.shape[1] > 1:  
    y_pred_probs = y_pred  
else:
    y_pred_probs = np.hstack([1 - y_pred, y_pred])

#Visualización de resultados
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(20, 4)

#Matriz de confusión
matriz = confusion_matrix(y_val_1d, y_pred.argmax(axis=1))  
ax = axes[0]
sns.heatmap(matriz, annot=True, ax=ax, cmap="Blues", fmt="d")
ax.set_title("Rec=" + str(round(recall_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Acc=" + str(round(accuracy_score(y_val_1d, y_pred.argmax(axis=1)), 2)) +
            " F1=" + str(round(f1_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Pre=" + str(round(precision_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)))
axes[0].set_xlabel('Predicción')
axes[0].set_ylabel('Real')

# 2. Curvas ROC 
fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):  
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), 
                                  np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])

    # Graficamos la curva ROC
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title(f'Curva ROC Clase {i}, AUC={round(roc_auc[i],2)}')

plt.tight_layout()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ### Modelo 2 best params Sequential

# %%
modelo_emb = Sequential()
modelo_emb.add(Embedding(input_dim=tamano_vocabulario, output_dim=64))
modelo_emb.add(GlobalAveragePooling1D())
modelo_emb.add(Dense(64, activation='relu'))
modelo_emb.add(Dense(Y.shape[1], activation="softmax"))

modelo_emb.compile(optimizer="Adam",
                  loss="categorical_crossentropy",
                  metrics=["acc"])

tag = "emb_" + datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = "logs/fit/" + tag
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
earlystopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_acc",
                                                         patience=4,
                                                         restore_best_weights=True)
#Guardar el modelo
modelo_emb.save(f'modelos/modelo_{tag}.keras')

# Predicciones y evaluación
y_pred_probs = modelo_emb.predict(x_val)
y_pred = np.argmax(y_pred_probs, axis=1)
y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))

# %%
# Crear una clase envoltorio para el modelo de Keras
class KerasModel(BaseEstimator, ClassifierMixin):
    def __init__(self, tamano_vocabulario=10000, embedding_dim=64, hidden_units=64, optimizer='adam', epochs=10, batch_size=32):
        self.tamano_vocabulario = tamano_vocabulario
        self.embedding_dim = embedding_dim
        self.hidden_units = hidden_units
        self.optimizer = optimizer
        self.epochs = epochs
        self.batch_size = batch_size

    def build_model(self):
        modelo = Sequential()
        modelo.add(Embedding(input_dim=self.tamano_vocabulario, output_dim=self.embedding_dim))
        modelo.add(GlobalAveragePooling1D())
        modelo.add(Dense(self.hidden_units, activation='relu'))
        modelo.add(Dense(Y.shape[1], activation="softmax"))
        
        optimizer = Adam() if self.optimizer == 'adam' else RMSprop()
        
        modelo.compile(optimizer=optimizer,
                      loss="categorical_crossentropy",
                      metrics=["acc"])
        return modelo

    def fit(self, X, y):
        self.model = self.build_model()  # Construir el modelo
        self.model.fit(X, y, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
        return self

    def predict(self, X):
        return self.model.predict(X, batch_size=self.batch_size)

x_train, x_val, y_train, y_val = train_test_split(X, Y, random_state=0)

x_train = np.asarray(x_train)
y_train = np.asarray(y_train)
x_val = np.asarray(x_val)
y_val = np.asarray(y_val)

# Definir el espacio de búsqueda de los hiperparámetros
parametros = {
    'tamano_vocabulario': [10000, 15000],
    'embedding_dim': [64, 128],
    'hidden_units': [64, 128],
    'optimizer': ['adam', 'rmsprop'],
    'epochs': [10],  
    'batch_size': [32] 
}

grid_search = GridSearchCV(estimator=KerasModel(), param_grid=parametros, cv=3)
grid_search.fit(x_train, y_train)  

# Obtener los mejores parámetros y el modelo resultante
mejores_parametros = grid_search.best_params_
mejor_modelo = grid_search.best_estimator_
print("Mejores parámetros:", mejores_parametros)

y_pred_probs = mejor_modelo.predict(x_val)
y_pred = np.argmax(y_pred_probs, axis=1)
y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))

tag = "emb_" + datetime.now().strftime("%Y%m%d-%H%M%S")
modelo_final = mejor_modelo.model 
modelo_final.save(f'modelos/modelo_{tag}.keras')

conf_mat = confusion_matrix(y_val_1d, y_pred)
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="Blues")
plt.title("Matriz de Confusión")
plt.show()

print("Precisión del modelo en los datos de validación:", accuracy_score(y_val_1d, y_pred))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Mejores parámetros: {'batch_size': 32, 'embedding_dim': 64, 'epochs': 10, 'hidden_units': 64, 'optimizer': 'adam', 'tamano_vocabulario': 10000}
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Precisión del modelo en los datos de validación: 0.7049180327868853

# %%
# Obtener las predicciones del modelo final
y_pred = modelo_final.predict(x_val)

# Ajuste de las predicciones de acuerdo a la forma de la salida
if y_pred.shape[1] > 1:
    y_pred_probs = y_pred
else:
    y_pred_probs = np.hstack([1 - y_pred, y_pred])

# Visualización de resultados
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(20, 4)

# 1. Matriz de confusión
matriz = confusion_matrix(y_val_1d, y_pred.argmax(axis=1))  
ax = axes[0]
sns.heatmap(matriz, annot=True, ax=ax, cmap="Blues", fmt="d")
ax.set_title("Rec=" + str(round(recall_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Acc=" + str(round(accuracy_score(y_val_1d, y_pred.argmax(axis=1)), 2)) +
            " F1=" + str(round(f1_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Pre=" + str(round(precision_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)))
axes[0].set_xlabel('Predicción')
axes[0].set_ylabel('Real')

# 2. Curvas ROC para cada una de las clases
fpr = {}
tpr = {}
roc_auc = {}
for i in range(y_pred.shape[1]):  # Número de clases (dinámico en función de la salida del modelo)
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), 
                                  np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])

    # Graficamos la curva ROC
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title(f'Curva ROC Clase {i}, AUC={round(roc_auc[i], 2)}')

plt.tight_layout()
plt.show()

# Visualización de la precisión, pérdida y curvas ROC
fig, axes = plt.subplots(1, 2, figsize=(20, 5))

# Pérdida durante el entrenamiento (solo si tienes `historia_final` del ajuste)
axes[0].plot(historia_final.history['loss'], label='Pérdida de entrenamiento')
axes[0].plot(historia_final.history['val_loss'], label='Pérdida de validación')
axes[0].set_title('Pérdida durante el entrenamiento')
axes[0].set_xlabel('Épocas')
axes[0].set_ylabel('Pérdida')
axes[0].legend()

# Precisión durante el entrenamiento (solo si tienes `historia_final` del ajuste)
axes[1].plot(historia_final.history['accuracy'], label='Precisión de entrenamiento')
axes[1].plot(historia_final.history['val_accuracy'], label='Precisión de validación')
axes[1].set_title('Precisión durante el entrenamiento')
axes[1].set_xlabel('Épocas')
axes[1].set_ylabel('Precisión')
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step

# %% [markdown]
# ### Modelo 3 Mejores parametros

# %%
# Definir función para construir el modelo Transformer
def crear_modelo(tamano_vocabulario=10000, num_heads=2, key_dim=32, dense_units=64, dropout_rate=0.1):
    inputs = Input(shape=(X.shape[1],))
    embedding = Embedding(input_dim=tamano_vocabulario, output_dim=64)(inputs)

    # Bloque de atención
    attention = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(embedding, embedding)
    attention = Dropout(dropout_rate)(attention)
    attention = LayerNormalization(epsilon=1e-6)(attention)

    # Red neuronal feed-forward
    ff = Dense(dense_units, activation="relu")(attention)
    ff = Dense(dense_units)(ff)
    ff = Dropout(dropout_rate)(ff)
    ff = LayerNormalization(epsilon=1e-6)(ff)

    # Capa final
    pooling = GlobalAveragePooling1D()(ff)
    outputs = Dense(Y.shape[1], activation="softmax")(pooling)

    # Construcción del modelo
    modelo_transformer = Model(inputs=inputs, outputs=outputs)
    
    # Compilación del modelo
    modelo_transformer.compile(optimizer="Adam",
                               loss="categorical_crossentropy",
                               metrics=["accuracy"])  # Aseguramos que 'accuracy' es la métrica correcta
    
    return modelo_transformer

# Definir el grid de hiperparámetros
param_grid = {
    'tamano_vocabulario': [10000, 15000],
    'num_heads': [2, 4],
    'key_dim': [32, 64],
    'dense_units': [64, 128],
    'dropout_rate': [0.1, 0.2]
}

# Generar todas las combinaciones de parámetros
grid = ParameterGrid(param_grid)
resultados = []

for params in grid:
    print(f"Entrenando con parámetros: {params}")
    
    modelo_transformer = crear_modelo(**params)

    # Configurar el entrenamiento
    tag = "transformer_" + datetime.now().strftime("%Y%m%d-%H%M%S")
    log_dir = "logs/fit/" + tag
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    earlystopping_callback = EarlyStopping(monitor="val_accuracy", patience=4, restore_best_weights=True)
    
    # Entrenar el modelo
    historia_transformer = modelo_transformer.fit(x_train, y_train,
                                                 validation_data=(x_val, y_val),
                                                 batch_size=32, epochs=16, verbose=2,
                                                 callbacks=[tensorboard_callback, earlystopping_callback])

    # Evaluar el modelo
    y_pred_probs = modelo_transformer.predict(x_val)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))

    # Almacenar los resultados
    resultados.append({
        'params': params,
        'accuracy': np.round(historia_transformer.history['val_accuracy'][-1], 4),
        'loss': np.round(historia_transformer.history['val_loss'][-1], 4),
        'f1': f1_score(y_val_1d, y_pred, average="macro"),
        'precision': precision_score(y_val_1d, y_pred, average="macro"),
        'recall': recall_score(y_val_1d, y_pred, average="macro")
    })

resultados_df = pd.DataFrame(resultados)
print(resultados_df)

# Encontrar los mejores parámetros basados en la precisión
mejores_resultados = resultados_df.loc[resultados_df['accuracy'].idxmax()]
print(f"Mejores parámetros: {mejores_resultados['params']}")

# Entrenar el mejor modelo con los mejores parámetros encontrados
mejores_parametros = mejores_resultados['params']
mejor_modelo = crear_modelo(**mejores_parametros)

# Entrenar el mejor modelo
mejor_modelo.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=32, epochs=16)

# Guardar el mejor modelo
mejor_modelo.save(f'modelos/modelo_transformer_best_{datetime.now().strftime("%Y%m%d-%H%M%S")}.keras')
# Out:
# Entrenando con parámetros: {'dense_units': 64, 'dropout_rate': 0.1, 'key_dim': 32, 'num_heads': 2, 'tamano_vocabulario': 10000}
# Epoch 1/16
# 29/29 - 4s - 124ms/step - accuracy: 0.6459 - loss: 0.9341 - val_accuracy: 0.6689 - val_loss: 0.8756
# Epoch 2/16
# 29/29 - 1s - 17ms/step - accuracy: 0.6656 - loss: 0.8636 - val_accuracy: 0.6689 - val_loss: 0.8420
# Epoch 3/16
# 29/29 - 1s - 18ms/step - accuracy: 0.6667 - loss: 0.8320 - val_accuracy: 0.6689 - val_loss: 0.7771
# Epoch 4/16
# 29/29 - 1s - 19ms/step - accuracy: 0.6929 - loss: 0.7493 - val_accuracy: 0.7967 - val_loss: 0.5597
# Epoch 5/16
# 29/29 - 1s - 17ms/step - accuracy: 0.7956 - loss: 0.5193 - val_accuracy: 0.8721 - val_loss: 0.3461
# Epoch 6/16
# 29/29 - 1s - 19ms/step - accuracy: 0.8929 - loss: 0.3081 - val_accuracy: 0.9148 - val_loss: 0.2778
# Epoch 7/16
# 29/29 - 1s - 17ms/step - accuracy: 0.9311 - loss: 0.2295 - val_accuracy: 0.9082 - val_loss: 0.2879
# Epoch 8/16
# 29/29 - 1s - 18ms/step - accuracy: 0.9344 - loss: 0.1930 - val_accuracy: 0.9213 - val_loss: 0.2632
# Epoch 9/16
# 29/29 - 1s - 18ms/step - accuracy: 0.9410 - loss: 0.1902 - val_accuracy: 0.9279 - val_loss: 0.3379
# Epoch 10/16
# 29/29 - 1s - 19ms/step - accuracy: 0.9530 - loss: 0.1616 - val_accuracy: 0.9279 - val_loss: 0.2832
# Epoch 11/16
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#                                                params  accuracy    loss  \
# 0   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.8918  0.3702
# 1   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.8918  0.4534
# 2   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.6689  0.8631
# 3   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.6689  0.7692
# 4   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.8885  0.4236
# 5   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.8918  0.3716
# 6   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.6689  0.8830
# 7   {'dense_units': 64, 'dropout_rate': 0.1, 'key_...    0.6689  0.8108
# 8   {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.9049  0.4902
# 9   {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.9311  0.3260
# 10  {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.6689  0.8461
# 11  {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.9115  0.3230
# 12  {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.8721  0.4060
# 13  {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.9016  0.4184
# 14  {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.9279  0.3119
# 15  {'dense_units': 64, 'dropout_rate': 0.2, 'key_...    0.6689  0.8549
# 16  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.8984  0.3723
# 17  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.9016  0.3670
# 18  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.8885  0.4264
# 19  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.9049  0.3201
# 20  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.9115  0.3110
# 21  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.8918  0.4278
# 22  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.6689  0.8031
# 23  {'dense_units': 128, 'dropout_rate': 0.1, 'key...    0.8885  0.4917
# 24  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.9049  0.4238
# 25  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.9049  0.3921
# 26  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.6689  0.8453
# 27  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.9016  0.3895
# 28  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.9049  0.3236
# 29  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.9049  0.3798
# 30  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.8623  0.4126
# 31  {'dense_units': 128, 'dropout_rate': 0.2, 'key...    0.9049  0.3178
#
#           f1  precision    recall
# 0   0.900610   0.911417  0.890838
# 1   0.902402   0.893095  0.913478
# 2   0.267191   0.222951  0.333333
# 3   0.267191   0.222951  0.333333
# 4   0.898002   0.890168  0.907068
# 5   0.889114   0.885202  0.893855
# 6   0.267191   0.222951  0.333333
# 7   0.267191   0.222951  0.333333
# 8   0.895129   0.892810  0.897515
# 9   0.899513   0.907662  0.892865
# 10  0.267191   0.222951  0.333333
# 11  0.904398   0.906840  0.902025
# 12  0.896358   0.898804  0.893981
# 13  0.903713   0.901920  0.905560
# 14  0.906041   0.893084  0.921522
# 15  0.267191   0.222951  0.333333
# 16  0.893943   0.904472  0.884428
# 17  0.899546   0.893823  0.905560
# 18  0.910808   0.913250  0.908435
# 19  0.895082   0.881453  0.911844
# 20  0.890745   0.903381  0.879652
# 21  0.907672   0.894542  0.924665
# 22  0.267191   0.222951  0.333333
# 23  0.899072   0.888651  0.911844
# 24  0.886658   0.892264  0.883579
# 25  0.907921   0.912316  0.903659
# 26  0.267191   0.222951  0.333333
# 27  0.891063   0.904120  0.879259
# 28  0.898002   0.890168  0.907068
# 29  0.889121   0.909606  0.873634
# 30  0.908905   0.909491  0.908435
# 31  0.887617   0.914135  0.868858
# Mejores parámetros: {'dense_units': 64, 'dropout_rate': 0.2, 'key_dim': 32, 'num_heads': 2, 'tamano_vocabulario': 15000}
# Epoch 1/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.6079 - loss: 1.0059 - val_accuracy: 0.6689 - val_loss: 0.9358
# Epoch 2/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6748 - loss: 0.8715 - val_accuracy: 0.6689 - val_loss: 0.8933
# Epoch 3/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6579 - loss: 0.8689 - val_accuracy: 0.6689 - val_loss: 0.8499
# Epoch 4/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6718 - loss: 0.8170 - val_accuracy: 0.7443 - val_loss: 0.6248
# Epoch 5/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7378 - loss: 0.6443 - val_accuracy: 0.8164 - val_loss: 0.4636
# Epoch 6/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8119 - loss: 0.4787 - val_accuracy: 0.8754 - val_loss: 0.3191
# Epoch 7/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9235 - loss: 0.2703 - val_accuracy: 0.9213 - val_loss: 0.2811
# Epoch 8/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9426 - loss: 0.2083 - val_accuracy: 0.9115 - val_loss: 0.2810
# Epoch 9/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9442 - loss: 0.1887 - val_accuracy: 0.9279 - val_loss: 0.2856
# Epoch 10/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9647 - loss: 0.1240 - val_accuracy: 0.8328 - val_loss: 0.5465
# Epoch 11/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9367 - loss: 0.2071 - val_accuracy: 0.8951 - val_loss: 0.4016
# Epoch 12/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9422 - loss: 0.1972 - val_accuracy: 0.9180 - val_loss: 0.2936
# Epoch 13/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9502 - loss: 0.1454 - val_accuracy: 0.9311 - val_loss: 0.2804
# Epoch 14/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9613 - loss: 0.1264 - val_accuracy: 0.9279 - val_loss: 0.2922
# Epoch 15/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9696 - loss: 0.1067 - val_accuracy: 0.8721 - val_loss: 0.4479
# Epoch 16/16
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9569 - loss: 0.1135 - val_accuracy: 0.8852 - val_loss: 0.4087

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

y_pred_probs = modelo_transformer.predict(x_val)

if y_pred_probs.shape[1] > 1:
    y_pred = y_pred_probs
else:
    y_pred = np.hstack([1 - y_pred_probs, y_pred_probs])

y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))

# Visualización de resultados
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(20, 4)

# Matriz de confusión
matriz = confusion_matrix(y_val_1d, y_pred.argmax(axis=1))  
ax = axes[0]
sns.heatmap(matriz, annot=True, ax=ax, cmap="Blues", fmt="d")
ax.set_title("Rec=" + str(round(recall_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Acc=" + str(round(accuracy_score(y_val_1d, y_pred.argmax(axis=1)), 2)) +
            " F1=" + str(round(f1_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Pre=" + str(round(precision_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)))
axes[0].set_xlabel('Predicción')
axes[0].set_ylabel('Real')

#  Curvas ROC 
fpr = {}
tpr = {}
roc_auc = {}
for i in range(y_pred.shape[1]):  
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])

    #Curva ROC
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title(f'Curva ROC Clase {i}, AUC={round(roc_auc[i], 2)}')

plt.tight_layout()
plt.show()

# Visualización de la precisión, pérdida y curvas ROC
fig, axes = plt.subplots(1, 2, figsize=(20, 5))

# Pérdida durante el entrenamiento 
axes[0].plot(historia_transformer.history['loss'], label='Pérdida de entrenamiento')
axes[0].plot(historia_transformer.history['val_loss'], label='Pérdida de validación')
axes[0].set_title('Pérdida durante el entrenamiento')
axes[0].set_xlabel('Épocas')
axes[0].set_ylabel('Pérdida')
axes[0].legend()

# Precisión durante el entrenamiento 
axes[1].plot(historia_transformer.history['accuracy'], label='Precisión de entrenamiento')
axes[1].plot(historia_transformer.history['val_accuracy'], label='Precisión de validación')
axes[1].set_title('Precisión durante el entrenamiento')
axes[1].set_xlabel('Épocas')
axes[1].set_ylabel('Precisión')
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# ### Modelo de Salida optimizado

# %%
# Calcular el F1 Macro
class F1Macro(Metric):
    def __init__(self, name="f1_macro", **kwargs):
        super(F1Macro, self).__init__(name=name, **kwargs)
        self.precision_metric = tf.keras.metrics.Precision()
        self.recall_metric = tf.keras.metrics.Recall()
        self.f1 = self.add_weight(name="f1", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.argmax(y_pred, axis=1)
        y_true = K.argmax(y_true, axis=1)
        
        self.precision_metric.update_state(y_true, y_pred)
        self.recall_metric.update_state(y_true, y_pred)
        
        precision = self.precision_metric.result()
        recall = self.recall_metric.result()
        f1 = 2 * (precision * recall) / (precision + recall + K.epsilon())
        
        self.f1.assign(f1)

    def result(self):
        return self.f1

    def reset_states(self):
        self.precision_metric.reset_states()
        self.recall_metric.reset_states()
        self.f1.assign(0)

# %%
# Mejores Parametros
params = {
    'dense_units': 64,
    'dropout_rate': 0.2,
    'key_dim': 32,
    'num_heads': 2,
    'tamano_vocabulario': 15000
}

modelo_transformer = crear_modelo(**params)
tag = "transformer_" + datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = "logs/fit/" + tag
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
earlystopping_callback = EarlyStopping(monitor="val_f1_macro", mode="max", patience=4, restore_best_weights=True)

# Entrenar el modelo
historia_transformer = modelo_transformer.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    batch_size=32, epochs=16, verbose=2,
    callbacks=[tensorboard_callback, earlystopping_callback]
)

# Evaluar el modelo
y_pred_probs = modelo_transformer.predict(x_val)
y_pred = np.argmax(y_pred_probs, axis=1)
y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))
resultados = {
    'accuracy': np.round(historia_transformer.history['val_accuracy'][-1], 4),
    'loss': np.round(historia_transformer.history['val_loss'][-1], 4),
    'f1': f1_score(y_val_1d, y_pred, average="macro"),
    'precision': precision_score(y_val_1d, y_pred, average="macro"),
    'recall': recall_score(y_val_1d, y_pred, average="macro")
}

print(resultados)
# Out:
# Epoch 1/16
# 29/29 - 4s - 133ms/step - accuracy: 0.6273 - f1_macro: 0.0506 - loss: 0.9666 - val_accuracy: 0.6689 - val_f1_macro: 0.0000e+00 - val_loss: 0.8993
# Epoch 2/16
# 29/29 - 1s - 20ms/step - accuracy: 0.6656 - f1_macro: 0.0000e+00 - loss: 0.8648 - val_accuracy: 0.6689 - val_f1_macro: 0.0000e+00 - val_loss: 0.8920
# Epoch 3/16
# 29/29 - 1s - 21ms/step - accuracy: 0.6656 - f1_macro: 0.0000e+00 - loss: 0.8534 - val_accuracy: 0.6689 - val_f1_macro: 0.0000e+00 - val_loss: 0.8917
# Epoch 4/16
# 29/29 - 1s - 20ms/step - accuracy: 0.6667 - f1_macro: 0.0065 - loss: 0.8421 - val_accuracy: 0.6689 - val_f1_macro: 0.0000e+00 - val_loss: 0.7783
# Epoch 5/16
# 29/29 - 1s - 20ms/step - accuracy: 0.7716 - f1_macro: 0.5839 - loss: 0.5782 - val_accuracy: 0.9049 - val_f1_macro: 0.9020 - val_loss: 0.3305
# Epoch 6/16
# 29/29 - 1s - 20ms/step - accuracy: 0.9301 - f1_macro: 0.9085 - loss: 0.2505 - val_accuracy: 0.9213 - val_f1_macro: 0.9118 - val_loss: 0.2841
# Epoch 7/16
# 29/29 - 1s - 20ms/step - accuracy: 0.9388 - f1_macro: 0.9138 - loss: 0.1887 - val_accuracy: 0.9049 - val_f1_macro: 0.8962 - val_loss: 0.3016
# Epoch 8/16
# 29/29 - 1s - 20ms/step - accuracy: 0.9464 - f1_macro: 0.9238 - loss: 0.1660 - val_accuracy: 0.9016 - val_f1_macro: 0.8763 - val_loss: 0.3573
# Epoch 9/16
# 29/29 - 1s - 21ms/step - accuracy: 0.9508 - f1_macro: 0.9293 - loss: 0.1443 - val_accuracy: 0.9213 - val_f1_macro: 0.9091 - val_loss: 0.3279
# Epoch 10/16
# 29/29 - 1s - 21ms/step - accuracy: 0.9443 - f1_macro: 0.9196 - loss: 0.1501 - val_accuracy: 0.8623 - val_f1_macro: 0.8546 - val_loss: 0.4813
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'accuracy': 0.8623, 'loss': 0.4813, 'f1': 0.8877857774409499, 'precision': 0.883480429490913, 'recall': 0.8923466822626486}

# %%
y_pred_probs = modelo_transformer.predict(x_val)

if y_pred_probs.shape[1] > 1:
    y_pred = y_pred_probs
else:
    y_pred = np.hstack([1 - y_pred_probs, y_pred_probs])

y_val_1d = np.squeeze(np.asarray(np.argmax(y_val, axis=1)))

# Visualización de resultados
fig, axes = plt.subplots(1, 4)
fig.set_size_inches(20, 4)

# Matriz de confusión
matriz = confusion_matrix(y_val_1d, y_pred.argmax(axis=1))  
ax = axes[0]
sns.heatmap(matriz, annot=True, ax=ax, cmap="Blues", fmt="d")
ax.set_title("Rec=" + str(round(recall_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Acc=" + str(round(accuracy_score(y_val_1d, y_pred.argmax(axis=1)), 2)) +
            " F1=" + str(round(f1_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)) +
            " Pre=" + str(round(precision_score(y_val_1d, y_pred.argmax(axis=1), average="macro"), 2)))
axes[0].set_xlabel('Predicción')
axes[0].set_ylabel('Real')

# Curvas ROC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(y_pred.shape[1]):  
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title(f'Curva ROC Clase {i}, AUC={round(roc_auc[i], 2)}')

plt.tight_layout()
plt.show()

# Visualización de la precisión, pérdida y curvas ROC
fig, axes = plt.subplots(1, 2, figsize=(20, 5))

# Pérdida durante el entrenamiento
axes[0].plot(historia_transformer.history['loss'], label='Pérdida de entrenamiento')
axes[0].plot(historia_transformer.history['val_loss'], label='Pérdida de validación')
axes[0].set_title('Pérdida durante el entrenamiento')
axes[0].set_xlabel('Épocas')
axes[0].set_ylabel('Pérdida')
axes[0].legend()

# Precisión durante el entrenamiento
axes[1].plot(historia_transformer.history['accuracy'], label='Precisión de entrenamiento')
axes[1].plot(historia_transformer.history['val_accuracy'], label='Precisión de validación')
axes[1].set_title('Precisión durante el entrenamiento')
axes[1].set_xlabel('Épocas')
axes[1].set_ylabel('Precisión')
axes[1].legend()

plt.tight_layout()
plt.show()

# Visualización de F1 Macro durante el entrenamiento
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(historia_transformer.history['f1_macro'], label='F1 Macro de entrenamiento')
ax.plot(historia_transformer.history['val_f1_macro'], label='F1 Macro de validación')
ax.set_title('F1 Macro durante el entrenamiento')
ax.set_xlabel('Épocas')
ax.set_ylabel('F1 Macro')
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
